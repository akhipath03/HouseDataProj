# %%
import pandas as pd
import numpy as np

# %%
prelim_data = pd.read_csv(r'C:\Users\akhip\OneDrive\Desktop\HouseDataProj\realtor-data.csv')
prelim_data.head()
# Out:
#      status     price  bed  bath  acre_lot  \
# 0  for_sale  105000.0  3.0   2.0      0.12
# 1  for_sale   80000.0  4.0   2.0      0.08
# 2  for_sale   67000.0  2.0   1.0      0.15
# 3  for_sale  145000.0  4.0   2.0      0.10
# 4  for_sale   65000.0  6.0   2.0      0.05
#
#                                         full_address  \
# 0  Sector Yahuecas Titulo # V84, Adjuntas, PR, 00601
# 1            Km 78 9 Carr # 135, Adjuntas, PR, 00601
# 2            556G 556-G 16 St, Juana Diaz, PR, 00795
# 3  R5 Comunidad El Paraso Calle De Oro R-5 Ponce,...
# 4                    14 Navarro, Mayaguez, PR, 00680
#
#                                           street        city        state  \
# 0                   Sector Yahuecas Titulo # V84    Adjuntas  Puerto Rico
# 1                             Km 78 9 Carr # 135    Adjuntas  Puerto Rico
# 2                               556G 556-G 16 St  Juana Diaz  Puerto Rico
# 3  R5 Comunidad El Paraso Calle De Oro R-5 Ponce       Ponce  Puerto Rico
# 4                                     14 Navarro    Mayaguez  Puerto Rico
#
#    zip_code  house_size sold_date
# 0     601.0       920.0       NaN
# 1     601.0      1527.0       NaN
# 2     795.0       748.0       NaN
# 3     731.0      1800.0       NaN
# 4     680.0         NaN       NaN

# %%
prelim_data['state'].fillna(method='ffill', inplace = True)
prelim_data.head()
# Out:
#      status     price  bed  bath  acre_lot  \
# 0  for_sale  105000.0  3.0   2.0      0.12
# 1  for_sale   80000.0  4.0   2.0      0.08
# 2  for_sale   67000.0  2.0   1.0      0.15
# 3  for_sale  145000.0  4.0   2.0      0.10
# 4  for_sale   65000.0  6.0   2.0      0.05
#
#                                         full_address  \
# 0  Sector Yahuecas Titulo # V84, Adjuntas, PR, 00601
# 1            Km 78 9 Carr # 135, Adjuntas, PR, 00601
# 2            556G 556-G 16 St, Juana Diaz, PR, 00795
# 3  R5 Comunidad El Paraso Calle De Oro R-5 Ponce,...
# 4                    14 Navarro, Mayaguez, PR, 00680
#
#                                           street        city        state  \
# 0                   Sector Yahuecas Titulo # V84    Adjuntas  Puerto Rico
# 1                             Km 78 9 Carr # 135    Adjuntas  Puerto Rico
# 2                               556G 556-G 16 St  Juana Diaz  Puerto Rico
# 3  R5 Comunidad El Paraso Calle De Oro R-5 Ponce       Ponce  Puerto Rico
# 4                                     14 Navarro    Mayaguez  Puerto Rico
#
#    zip_code  house_size sold_date
# 0     601.0       920.0       NaN
# 1     601.0      1527.0       NaN
# 2     795.0       748.0       NaN
# 3     731.0      1800.0       NaN
# 4     680.0         NaN       NaN

# %%
NJ_df = prelim_data[prelim_data['state'] == 'New Jersey']
NJ_df.head()
# Out:
#           status     price  bed  bath  acre_lot  \
# 30126   for_sale  333490.0  3.0   3.0      0.07
# 45320   for_sale  333490.0  3.0   3.0      0.07
# 385082  for_sale  333490.0  3.0   3.0      0.07
# 388797  for_sale  333490.0  3.0   3.0      0.07
# 389915  for_sale  333490.0  3.0   3.0      0.07
#
#                             full_address     street        city       state  \
# 30126   Katherine, Burlington, NJ, 08016  Katherine  Burlington  New Jersey
# 45320   Katherine, Burlington, NJ, 08016  Katherine  Burlington  New Jersey
# 385082  Katherine, Burlington, NJ, 08016  Katherine  Burlington  New Jersey
# 388797  Katherine, Burlington, NJ, 08016  Katherine  Burlington  New Jersey
# 389915  Katherine, Burlington, NJ, 08016  Katherine  Burlington  New Jersey
#
#         zip_code  house_size sold_date
# 30126     8016.0      1500.0       NaN
# 45320     8016.0      1500.0       NaN
# 385082    8016.0      1500.0       NaN
# 388797    8016.0      1500.0       NaN
# 389915    8016.0      1500.0       NaN

# %%
columns_to_drop = ['status', 'full_address', 'street', 'sold_date', 'city']  # List of column names to drop
NJ_drop = NJ_df.drop(columns=columns_to_drop)

# %%
NJ_drop.head()
NJ_drop.shape
# Out:
# (191280, 7)

# %%
deduplicated_df = NJ_drop.drop_duplicates()
deduplicated_df.shape
# Out:
# (31668, 7)

# %%
NJ_index = deduplicated_df.reset_index(drop=True)
NJ_index = NJ_index.rename_axis("idx", axis=1)
NJ_index.head()
# Out:
# idx     price  bed  bath  acre_lot       state  zip_code  house_size
# 0    333490.0  3.0   3.0      0.07  New Jersey    8016.0      1500.0
# 1    339900.0  2.0   2.0      0.11  New Jersey    7001.0      1456.0
# 2    305100.0  3.0   2.0      0.14  New Jersey    7001.0      1542.0
# 3    205000.0  3.0   1.0      0.11  New Jersey    7001.0       925.0
# 4    479000.0  NaN   NaN      0.11  New Jersey    7001.0         NaN

# %%
NJ_index['zip_code'].isnull().values.any()
# Out:
# False

# %%
def calculate_mean(column):
    mean = NJ_index[column].mean()
    return mean

NJ_index['price'].fillna(value=calculate_mean('price'), inplace=True)
NJ_index['bed'].fillna(value=round(calculate_mean('bed')), inplace=True)
NJ_index['bath'].fillna(value=round(calculate_mean('bath')), inplace=True)
NJ_index['acre_lot'].fillna(value=calculate_mean('acre_lot'), inplace=True)
NJ_index['house_size'].fillna(value=round(calculate_mean('house_size')), inplace=True)
NJ_index.head()
# Out:
# idx     price  bed  bath  acre_lot       state  zip_code  house_size
# 0    333490.0  3.0   3.0      0.07  New Jersey    8016.0      1500.0
# 1    339900.0  2.0   2.0      0.11  New Jersey    7001.0      1456.0
# 2    305100.0  3.0   2.0      0.14  New Jersey    7001.0      1542.0
# 3    205000.0  3.0   1.0      0.11  New Jersey    7001.0       925.0
# 4    479000.0  3.0   3.0      0.11  New Jersey    7001.0      2330.0

# %%
NJ_index_copy = NJ_index
NJ_index.shape
# Out:
# (31668, 7)

# %%
def remove_outliers(df,columns,n_std):
    for col in columns:
        print('Working on column: {}'.format(col))
        
        mean = df[col].mean()
        sd = df[col].std()
        
        df = df[(df[col] <= mean+(n_std*sd))]
        
    return df

removed_outliers_df = remove_outliers(NJ_index_copy, ['bed', 'bath', 'acre_lot', 'price', 'house_size'], 3)
# Out:
# Working on column: bed
# Working on column: bath
# Working on column: acre_lot
# Working on column: price
# Working on column: house_size

# %%
removed_outliers_df.shape
# Out:
# (30050, 7)

# %%
removed_outliers_df['zip_code'] = removed_outliers_df['zip_code'].astype(str)
removed_outliers_df['zip_code'] = removed_outliers_df['zip_code'].str.replace('.', '')
removed_outliers_df.head()
# Out:
# idx     price  bed  bath  acre_lot       state zip_code  house_size
# 0    333490.0  3.0   3.0      0.07  New Jersey    80160      1500.0
# 1    339900.0  2.0   2.0      0.11  New Jersey    70010      1456.0
# 2    305100.0  3.0   2.0      0.14  New Jersey    70010      1542.0
# 3    205000.0  3.0   1.0      0.11  New Jersey    70010       925.0
# 4    479000.0  3.0   3.0      0.11  New Jersey    70010      2330.0

# %%
removed_outliers_df.dtypes
# Out:
# idx
# price         float64
# bed           float64
# bath          float64
# acre_lot      float64
# state          object
# zip_code       object
# house_size    float64
# dtype: object

# %%
data = removed_outliers_df

# %%
data.to_csv('Pre_processed.csv')

# %%
data.head()
# Out:
# idx     price  bed  bath  acre_lot       state zip_code  house_size
# 0    333490.0  3.0   3.0      0.07  New Jersey    80160      1500.0
# 1    339900.0  2.0   2.0      0.11  New Jersey    70010      1456.0
# 2    305100.0  3.0   2.0      0.14  New Jersey    70010      1542.0
# 3    205000.0  3.0   1.0      0.11  New Jersey    70010       925.0
# 4    479000.0  3.0   3.0      0.11  New Jersey    70010      2330.0

# %%
balls = pd.read_csv('Pre_processed.csv')
balls.head()
# Out:
#    Unnamed: 0     price  bed  bath  acre_lot       state  zip_code  house_size
# 0           0  333490.0  3.0   3.0      0.07  New Jersey     80160      1500.0
# 1           1  339900.0  2.0   2.0      0.11  New Jersey     70010      1456.0
# 2           2  305100.0  3.0   2.0      0.14  New Jersey     70010      1542.0
# 3           3  205000.0  3.0   1.0      0.11  New Jersey     70010       925.0
# 4           4  479000.0  3.0   3.0      0.11  New Jersey     70010      2330.0
